# %%
run simplest_v2.py
# Out:
# /home/b/anaconda3/envs/tf/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 88 from C header, got 96 from PyObject
#   return f(*args, **kwds)
# nb data =  1000
# -----------------------------------------------------
# ----------- 1k
# -----------------------------------------------------
# it=      0 - loss= 132.368515
# it=   1000 - loss= 43.697540
# it=   2000 - loss= 13.808051
# it=   3000 - loss= 26.302853
# it=   4000 - loss= 22.703102
# it=   5000 - loss= 20.708620
# it=   6000 - loss= 27.731255
# it=   7000 - loss= 27.179007
# it=   8000 - loss= 32.156307
# it=   9000 - loss= 9.238976
# it=  10000 - loss= 17.296768
# it=  11000 - loss= 11.055033
# it=  12000 - loss= 13.035420
# it=  13000 - loss= 18.788197
# it=  14000 - loss= 21.607166
# it=  15000 - loss= 27.076452
# it=  16000 - loss= 11.614191
# it=  17000 - loss= 14.728185
# it=  18000 - loss= 9.561745
# it=  19000 - loss= 12.367014
# ...
