# %%
run Main.py
# Out:
# nb data :  1000
# nb data :  10000
# unflat output   Tensor("CNN/Reshape:0", shape=(?, 48, 48, 1), dtype=float32)
# conv_1 input   Tensor("CNN/Reshape:0", shape=(?, 48, 48, 1), dtype=float32)
# conv_1 W   (3, 3, 1, 3)
# conv_3 input   Tensor("CNN/pool_2/MaxPool:0", shape=(?, 24, 24, 3), dtype=float32)
# conv_3 W   (3, 3, 3, 6)
# conv_5 input   Tensor("CNN/pool_4/MaxPool:0", shape=(?, 12, 12, 6), dtype=float32)
# conv_5 W   (3, 3, 6, 12)
# flat output   Tensor("CNN/Reshape_1:0", shape=(?, 432), dtype=float32)
# fc_7 input   Tensor("CNN/Reshape_1:0", shape=(?, 432), dtype=float32)
# fc_7 W   (432, 2)
# INFO:tensorflow:Summary name cross entropy is illegal; using cross_entropy instead.
# -----------------------------------------------------
# ----------- 1k
# -----------------------------------------------------
# it=      0 - cross_entropy= 0.606891 - acc= 0.445312
# it=     10 - cross_entropy= 0.418864 - acc= 0.562500
# it=     20 - cross_entropy= 0.358226 - acc= 0.523438
# ...
