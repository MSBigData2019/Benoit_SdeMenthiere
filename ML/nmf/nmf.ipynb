# %%
run icaaudio.py
# Out:
# /home/b/gitMSBGD/ML/nmf/icaaudio.py:18: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   s = np.fromstring(wf.readframes(wf.getnframes()), dtype=np.int16)

# %%
s1
# Out:
# array([   0,    0,    0, ..., -186, -117,   60], dtype=int16)

# %%
s2
# Out:
# array([  0,   0,   0, ..., -75, -75, -75], dtype=int16)

# %%
from sklearn.decomposition import FastICA

# %%
fica = FastICA(n_components=2)

# %%
x
# Out:
# array([  0. ,   0. ,   0. , ..., -96. ,   6. ,  -7.5])

# %%
r = fica.fit_transform(X)

# %%
wavwrite('./snd/s1.wav', r[:,0], nchannels=1)
wavwrite('./snd/s2.wav', r[:,1], nchannels=1)

# %%
run pcanmffaces.py
# Out:
# Dataset consists of 400 faces
# 2061 negative-valued pixels
# 2773 negative-valued pixels
# 2630 negative-valued pixels
# 1422 negative-valued pixels
# 1242 negative-valued pixels
# 1004 negative-valued pixels
# 2049 negative-valued pixels
# 1580 negative-valued pixels
# 1387 negative-valued pixels
# 3819 negative-valued pixels
# Extracting the top 10 Eigenfaces - PCA...
# done in 0.055s
# 3998 negative-valued pixels
# /home/b/anaconda3/envs/tf/lib/python3.6/site-packages/matplotlib/pyplot.py:3356: MatplotlibDeprecationWarning: The 'hold' keyword argument is deprecated since 2.0.
#   mplDeprecation)
# /home/b/anaconda3/envs/tf/lib/python3.6/site-packages/matplotlib/pyplot.py:3356: MatplotlibDeprecationWarning: The 'hold' keyword argument is deprecated since 2.0.
#   mplDeprecation)
# 2078 negative-valued pixels
# 1967 negative-valued pixels
# 1862 negative-valued pixels
# 2261 negative-valued pixels
# 1924 negative-valued pixels
# 1951 negative-valued pixels
# ...

# %%
labels
# Out:
# array([13, 30, 34, 19, 24,  6, 15, 26, 14, 21,  3, 13, 11, 34,  1,  5, 29,
#        14, 20, 19, 17, 26, 12, 34, 17, 31,  7,  1, 28, 10, 17, 30, 33, 22,
#         6,  7,  9, 17, 17, 39, 10, 32,  0,  0, 29,  5, 37, 25, 15, 23, 24,
#        14, 29, 17, 28, 31,  5,  1,  2,  4,  7, 27,  0, 35, 19, 37, 14,  0,
#        15, 31,  0, 26,  6,  2, 10,  1, 36, 30, 36, 32, 33,  6,  5, 10, 30,
#        22, 12, 37, 39, 32, 38, 25,  5,  0, 19, 14, 13, 39, 26, 36, 25,  6,
#        31, 15, 28, 34,  8, 34, 15, 29,  9,  8, 29,  2, 36, 21, 25,  4, 23,
#        34,  9, 22, 23, 23, 37, 14,  2, 25, 35, 16, 15, 39,  6, 24, 21, 10,
#        31, 19, 32,  1, 16, 18,  3, 11, 26, 10, 35, 24, 23, 11, 33, 12, 28,
#        11, 21, 13, 27, 12, 19, 29, 28, 13,  3, 37, 16,  3, 23,  9,  8,  6,
#        16, 28, 20, 39, 23, 28, 10,  4, 32, 39, 22,  7, 13, 38, 22, 21,  2,
#        18, 36, 27,  5, 32, 35,  2,  0, 21, 15, 21, 37, 22, 13, 23, 21, 27,
# ...

# %%
plt.imshow(X[0].reshape(image_shape))

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()

# %%
print(dataset.DESCR)
# Out:
# .. _olivetti_faces_dataset:
#
# The Olivetti faces dataset
# --------------------------
#
# `This dataset contains a set of face images`_ taken between April 1992 and
# April 1994 at AT&T Laboratories Cambridge. The
# :func:`sklearn.datasets.fetch_olivetti_faces` function is the data
# fetching / caching function that downloads the data
# archive from AT&T.
#
# .. _This dataset contains a set of face images: http://www.cl.cam.ac.uk/research/dtg/attarchive/facedatabase.html
#
# As described on the original website:
#
#     There are ten different images of each of 40 distinct subjects. For some
#     subjects, the images were taken at different times, varying the lighting,
#     facial expressions (open / closed eyes, smiling / not smiling) and facial
#     details (glasses / no glasses). All the images were taken against a dark
#     homogeneous background with the subjects in an upright, frontal position
#     (with tolerance for some side movement).
#
# ...

# %%
components_.shape
# Out:
# (10, 4096)

# %%
data.shape
# Out:
# (400, 10)

# %%
run pcanmffaces.py
# Out:
# Dataset consists of 400 faces
# 2061 negative-valued pixels
# 2773 negative-valued pixels
# 2630 negative-valued pixels
# 1422 negative-valued pixels
# 1242 negative-valued pixels
# Extracting the top 5 Eigenfaces - PCA...
# done in 0.053s
# 3996 negative-valued pixels
# 2080 negative-valued pixels
# 1974 negative-valued pixels
# 1856 negative-valued pixels
# 2265 negative-valued pixels
# scoring---------> [0.5625     0.625      0.58333333]
# Extracting the top 5 Non-negative components - NMF...
# /home/b/anaconda3/envs/tf/lib/python3.6/site-packages/matplotlib/pyplot.py:3356: MatplotlibDeprecationWarning: The 'hold' keyword argument is deprecated since 2.0.
#   mplDeprecation)
# /home/b/anaconda3/envs/tf/lib/python3.6/site-packages/matplotlib/pyplot.py:3356: MatplotlibDeprecationWarning: The 'hold' keyword argument is deprecated since 2.0.
#   mplDeprecation)
# done in 3.028s
# scoring---------> [0.5875     0.63333333 0.60833333]

# %%
run topicsextractionwithnmf.py
# Out:
# ...
# INFO:sklearn.datasets.twenty_newsgroups:Downloading 20news dataset. This may take a few minutes.
# ...
# INFO:sklearn.datasets.twenty_newsgroups:Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# Loading dataset and extracting TF-IDF features...
# done in 18.570s.
# done in 19.045s.
# Topic #0:
# the of in and on was to as at is which by were one with for they that when two
#
# Topic #1:
# chip clipper key the to encryption keys government be will this public as is or of can that it use
#
# Topic #2:
# is that of to not are and the we in as be people they it this there or god their
#
# Topic #3:
# edu university host posting cs nntp of re in article cc writes reply distribution washington cwru state mit for anyone
#
# Topic #4:
# com hp in article writes inc netcom corp stratus re sun posting nntp host dec ca jim org that corporation
#
# Topic #5:
# he his was to and him that who the had my in it but year this ca me team be
#
# Topic #6:
# ...

# %%
topic.argsort()
# Out:
# array([899, 644, 325, 646, 647, 649, 319, 318, 650, 316, 654, 330, 314,
#        311, 655, 658, 659, 661, 305, 665, 301, 298, 297, 313, 331, 332,
#        641, 367, 366, 625, 364, 634, 360, 359, 358, 357, 356, 355, 354,
#        353, 351, 638, 348, 347, 343, 342, 341, 340, 338, 337, 668, 368,
#        669, 292, 702, 704, 705, 706, 242, 236, 234, 232, 230, 720, 701,
#        228, 226, 224, 721, 221, 220, 219, 724, 217, 216, 215, 227, 700,
#        699, 698, 291, 290, 671, 288, 286, 285, 283, 673, 278, 276, 680,
#        274, 272, 681, 267, 266, 264, 684, 691, 259, 692, 257, 256, 670,
#        369, 370, 371, 470, 564, 566, 465, 570, 462, 461, 573, 457, 578,
#        559, 455, 451, 898, 448, 447, 445, 444, 443, 442, 441, 440, 454,
#        558, 476, 477, 521, 520, 526, 518, 517, 528, 515, 514, 536, 507,
#        506, 505, 502, 542, 499, 497, 493, 550, 489, 487, 483, 481, 556,
#        439, 579, 581, 435, 599, 600, 398, 397, 603, 604, 605, 606, 390,
# ...
