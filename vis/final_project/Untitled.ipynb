# %%
contexts = ['repúblika ng pilipina live color women unit state republ philippin phl philippin american femal singl skater femal burgo fourchett républiqu de philippin citi angel unit state tinseltown US figur skater 1980 winter olymp citi lo angel olymp figur skater unit state angeltown washington , d.c . live peopl freyburg american femal pair skater north border usa american figur skater philippin republika ng pilipina skater lo angel down south figur skater 1976 winter olymp olymp competitor unit state lasd lalaland american peopl filipino descent', 'pic movi move pictur moving-pictur show film argentin film spanish-languag film pictur motion-pictur show 1987 film 1980 drama film discepolo armando discepolo armando discépolo motion pictur pictur show flick']

# %%
content = 'tai reina babilonia american former pair skater'

# %%
set("tai reina babilonia american former pair skater".split())
# Out:
# {'american', 'babilonia', 'former', 'pair', 'reina', 'skater', 'tai'}

# %%
set(content)
# Out:
# {' ',
#  'a',
#  'b',
#  'c',
#  'e',
#  'f',
#  'i',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't'}

# %%
from nltk import jaccard_distance

# %%
[jaccard_distance(set(c),set(content)) for c in contexts]
# Out:
# [0.5555555555555556, 0.4827586206896552]

# %%
4
# Out:
# 4

# %%
import pandas as pd

# %%
df = pd.read_csv('./factbook.csv', sep=';', index_col=0, skiprows=[1])

# %%
df.head()
# Out:
#                 Area(sq km)  Birth rate(births/1000 population)  \
# Country
# Afghanistan          647500                               47.02
# Akrotiri                123                                 NaN
# Albania               28748                               15.08
# Algeria             2381740                               17.13
# American Samoa          199                               23.13
#
#                 Current account balance  Death rate(deaths/1000 population)  \
# Country
# Afghanistan                         NaN                               20.75
# Akrotiri                            NaN                                 NaN
# Albania                   -5.040000e+08                                5.12
# Algeria                    1.190000e+10                                4.60
# American Samoa                      NaN                                3.33
#
#                 Debt - external  Electricity - consumption(kWh)  \
# Country
# ...

# %%
hiv = [x for x in df.columns if 'HIV' in  x]

# %%
df[hiv].describe()
# Out:
#        HIV/AIDS - adult prevalence rate(%)  HIV/AIDS - deaths  \
# count                           168.000000         148.000000
# mean                              2.539702       19160.864865
# std                               5.920090       54059.423399
# min                               0.000000           0.000000
# 25%                               0.100000         200.000000
# 50%                               0.300000         900.000000
# 75%                               1.900000        9775.000000
# max                              38.800000      370000.000000
#
#        HIV/AIDS - people living with HIV/AIDS
# count                            1.640000e+02
# mean                             2.330337e+05
# std                              6.915343e+05
# min                              0.000000e+00
# 25%                              2.950000e+03
# 50%                              1.450000e+04
# 75%                              1.400000e+05
# ...

# %%
df.sample(10)
# Out:
#                                 Area(sq km)  \
# Country
# Belgium                               30528
# Bassas da India                           0
# Holy See (Vatican City)                   0
# Zambia                               752614
# Faroe Islands                          1399
# Peru                                1285220
# British Indian Ocean Territory           60
# Laos                                 236800
# Oman                                 212460
# Brunei                                 5770
#
#                                 Birth rate(births/1000 population)  \
# Country
# Belgium                                                      10.48
# Bassas da India                                                NaN
# Holy See (Vatican City)                                        NaN
# Zambia                                                       41.38
# Faroe Islands                                                13.97
# ...

# %%
df[df.count(1)>30]
# Out:
#                         Area(sq km)  Birth rate(births/1000 population)  \
# Country
# Afghanistan                  647500                               47.02
# Albania                       28748                               15.08
# Algeria                     2381740                               17.13
# Angola                      1246700                               44.64
# Argentina                   2766890                               16.90
# Armenia                       29800                               11.76
# Australia                   7686850                               12.26
# Austria                       83870                                8.81
# Azerbaijan                    86600                               20.40
# Bahrain                         665                               18.10
# Bangladesh                   144000                               30.01
# Barbados                        431                               12.83
# ...

# %%
list(df.columns)
# Out:
# ['Area(sq km)',
#  'Birth rate(births/1000 population)',
#  'Current account balance',
#  'Death rate(deaths/1000 population)',
#  'Debt - external',
#  'Electricity - consumption(kWh)',
#  'Electricity - production(kWh)',
#  'Exports',
#  'GDP',
#  'GDP - per capita',
#  'GDP - real growth rate(%)',
#  'HIV/AIDS - adult prevalence rate(%)',
#  'HIV/AIDS - deaths',
#  'HIV/AIDS - people living with HIV/AIDS',
#  'Highways(km)',
#  'Imports',
#  'Industrial production growth rate(%)',
#  'Infant mortality rate(deaths/1000 live births)',
#  'Inflation rate (consumer prices)(%)',
#  'Internet hosts',
#  'Internet users',
#  'Investment (gross fixed)(% of GDP)',
#  'Labor force',
#  'Life expectancy at birth(years)',
#  'Military expenditures - dollar figure',
#  'Military expenditures - percent of GDP(%)',
#  'Natural gas - consumption(cu m)',
#  'Natural gas - exports(cu m)',
#  'Natural gas - imports(cu m)',
#  'Natural gas - production(cu m)',
# ...

# %%
import ipywidgets

# %%
import cufflinks as cf

# %%
from ipywidgets import interact

# %%
@interact
def scatter_plot(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns)[1:],
                 log=list((True, False)), 
                 colorscale=list(cf.colors._scales_names.keys())):
    
    df.plot(kind='scatter', x=x, y=y, loglog=log)
# Out:
# interactive(children=(Dropdown(description='x', options=('Area(sq km)', 'Birth rate(births/1000 population)', …
